# %%
import requests

# %%
link = "https://www.goodreads.com/choiceawards/best-fiction-books-2023"

# %%
response = requests.get(link)

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Best Fiction 2023 — Goodreads Choice Awards</title>\n\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<meta property="keywords" content="Best books 2023, top books 2023, 2023 Goodreads Choice Awards, votes, ratings, book reviews" />\n<meta content=\'2415071772\' property=\'fb:app_id\'>\n<meta content=\'Announcing the Goodreads Choice Winner in Best Fiction!\' property=\'og:title\'>\n<meta content=\'https://s.gr-assets.com/assets/award/2023/choice-logo-square-winners.png\' property=\'og:image\'>\n<meta content=\'Congratulations to our winners in 15 categories! The Goodreads Choice Awards are the only major book awards decided by readers.\' property=\'og:description\'>\n<meta content=\'https://www.goodreads.com/choiceawards/best-fiction-books-2023\' property=\'og:url\'>\n<meta content=\'Goodreads\' property=\'og:site_name\'>\n\n\n\n\n  \n  <!-- * Copied from https://info.analytics.a2z.co
# ...

# %%
# !pip install markdownify

# %%
from markdownify import markdownify
md_text = markdownify(response.text)

# %%
print(md_text)
# Out:
# Best Fiction 2023 — Goodreads Choice Awards
#
#
#
#
#
#
#
#
#
#
#  //<![CDATA[
#  !function(){function n(n,t){var r=i(n);return t&&(r=r("instance",t)),r}var r=[],c=0,i=function(t){return function(){var n=c++;return r.push([t,[].slice.call(arguments,0),n,{time:Date.now()}]),i(n)}};n.\_s=r,this.csa=n}();
#
#  if (window.csa) {
#  window.csa("Config", {
#  "Application": "GoodreadsMonolith",
#  "Events.SushiEndpoint": "https://unagi.amazon.com/1/events/com.amazon.csm.csa.prod",
#  "Events.Namespace": "csa",
#  "CacheDetection.RequestID": "DJ8NRQWWMZRV4VWVYPB1",
#  "ObfuscatedMarketplaceId": "A1PQBFHBHS6YH1"
#  });
#
#  window.csa("Events")("setEntity", {
#  session: { id: "928-4661285-9915112" },
#  page: {requestId: "DJ8NRQWWMZRV4VWVYPB1", meaningful: "interactive"}
#  });
#  }
#
#  var e = document.createElement("script"); e.src = "https://m.media-amazon.com/images/I/41mrkPcyPwL.js"; document.head.appendChild(e);
#  //]]>
#
#
#  if (window.Mobvious === undefined) {
# ...
